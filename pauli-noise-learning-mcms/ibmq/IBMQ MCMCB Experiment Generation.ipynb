# %% [markdown]
# This notebook generates and runs an MCM-CB experiment on IBM Q cloud quantum processors. Running this requires an IBM Q account. This notebook is set up to generate a 4-qubit experiment with a single MCM and 3 idling qubits (as presented in the main text of "Pauli Noise Learning for Mid-Circuit Measurements"). It is readily adaptable to other system sizes (e.g. the 2-qubit example in the SM)

# %%
import numpy as np
import pygsti
import pygsti.baseobjs.label as _lbl
import pygsti.modelmembers as mm
from pygsti.circuits import Circuit as _cir
import pygsti.algorithms.randomcircuit as _rc
from pygsti.tools import symplectic as _symp
import itertools
from pygsti.processors import CliffordCompilationRules as CCR

from qiskit_ibm_runtime import QiskitRuntimeService, Sampler, Options, Session
from pygsti.extras import devices
from pygsti.extras import ibmq

from mcmrc import *

# %%
#IBMQ.load_account()
device_name = 'ibm_brisbane' #put the device name you want to use
service = QiskitRuntimeService()
backend = service.backend(device_name)

# %%
qubit_labels = ('Q40','Q41','Q42','Q43')
n = len(qubit_labels)
availability = {'Gcphase':[(f'Q{i}',f'Q{i+1}') for i in range(40,43)]}
gate_names = [f'Gc{i}' for i in range(24)]+['Gcphase']
pspec = pygsti.processors.QubitProcessorSpec(n, gate_names, availability=availability, qubit_labels=qubit_labels)

# %%
model = pygsti.models.modelconstruction.create_crosstalk_free_model(pspec)

# %%
depths = [0,2,4,8,12]
num_randomizations = 30
num_meas = 1
num_unmeas = 3
measured_qs = qubit_labels[:num_meas]
unmeasured_qs = [q for q in qubit_labels if q not in measured_qs]

cycle = pygsti.circuits.Circuit([[pygsti.baseobjs.label.Label('Iz',('Q40'))],[pygsti.baseobjs.label.Label('Gc0',f'{i}') for i in qubit_labels]])

# %%
compilations = {'absolute': CCR.create_standard(pspec, 'absolute', ('paulis', '1Qcliffords'), verbosity=0),            
                'paulieq': CCR.create_standard(pspec, 'paulieq', ('1Qcliffords', 'allcnots'), verbosity=0)}

# %%
unmeas_paulis = itertools.product(['I','X','Y','Z'], repeat=num_unmeas)
required_paulis = [('Z',)+p for p in unmeas_paulis]

# %%
edesigns = {}
cs_by_pauli, signs_by_pauli, tbs_by_pauli = generate_circuits_rc(cycle, depths, required_paulis, compilations, num_randomizations, qubit_labels)
for pauli, clists in cs_by_pauli.items():
    print(pauli)
    edesigns[pauli] = pygsti.protocols.ByDepthDesign(depths, clists)
ced = pygsti.protocols.CombinedExperimentDesign(edesigns)
# Out:
# ('Z', 'I', 'I', 'I')
# ('Z', 'I', 'I', 'X')
# ('Z', 'I', 'I', 'Y')
# ('Z', 'I', 'I', 'Z')
# ('Z', 'I', 'X', 'I')
# ('Z', 'I', 'X', 'X')
# ('Z', 'I', 'X', 'Y')
# ('Z', 'I', 'X', 'Z')
# ('Z', 'I', 'Y', 'I')
# ('Z', 'I', 'Y', 'X')
# ('Z', 'I', 'Y', 'Y')
# ('Z', 'I', 'Y', 'Z')
# ('Z', 'I', 'Z', 'I')
# ('Z', 'I', 'Z', 'X')
# ('Z', 'I', 'Z', 'Y')
# ('Z', 'I', 'Z', 'Z')
# ('Z', 'X', 'I', 'I')
# ('Z', 'X', 'I', 'X')
# ('Z', 'X', 'I', 'Y')
# ('Z', 'X', 'I', 'Z')
# ('Z', 'X', 'X', 'I')
# ('Z', 'X', 'X', 'X')
# ('Z', 'X', 'X', 'Y')
# ('Z', 'X', 'X', 'Z')
# ('Z', 'X', 'Y', 'I')
# ('Z', 'X', 'Y', 'X')
# ('Z', 'X', 'Y', 'Y')
# ('Z', 'X', 'Y', 'Z')
# ('Z', 'X', 'Z', 'I')
# ('Z', 'X', 'Z', 'X')
# ('Z', 'X', 'Z', 'Y')
# ('Z', 'X', 'Z', 'Z')
# ('Z', 'Y', 'I', 'I')
# ('Z', 'Y', 'I', 'X')
# ('Z', 'Y', 'I', 'Y')
# ('Z', 'Y', 'I', 'Z')
# ('Z', 'Y', 'X', 'I')
# ('Z', 'Y', 'X', 'X')
# ('Z', 'Y', 'X', 'Y')
# ('Z', 'Y', 'X', 'Z')
# ('Z', 'Y', 'Y', 'I')
# ('Z', 'Y', 'Y', 'X')
# ('Z', 'Y', 'Y', 'Y')
# ('Z', 'Y', 'Y', 'Z')
# ('Z', 'Y', 'Z', 'I')
# ('Z', 'Y', 'Z', 'X')
# ('Z', 'Y', 'Z', 'Y')
# ('Z', 'Y', 'Z', 'Z')
# ('Z', 'Z', 'I', 'I')
# ('Z', 'Z', 'I', 'X')
# ('Z', 'Z', 'I', 'Y')
# ('Z', 'Z', 'I', 'Z')
# ('Z', 'Z', 'X', 'I')
# ('Z', 'Z', 'X', 'X')
# ('Z', 'Z', 'X', 'Y')
# ('Z', 'Z', 'X', 'Z')
# ('Z', 'Z', 'Y', 'I')
# ('Z', 'Z', 'Y', 'X')
# ('Z', 'Z', 'Y', 'Y')
# ('Z', 'Z', 'Y', 'Z')
# ('Z', 'Z', 'Z', 'I')
# ('Z', 'Z', 'Z', 'X')
# ('Z', 'Z', 'Z', 'Y')
# ('Z', 'Z', 'Z', 'Z')

# %%
exp_dict = {'cs':cs_by_pauli, 'tbs':tbs_by_pauli, 'signs':signs_by_pauli}

# %%
qubit_labels = tuple(f'Q{i}' for i in range(44))
n = len(qubit_labels)
availability = {'Gcphase':[(f'Q{i}',f'Q{i+1}') for i in range(0,44)]}
gate_names = [f'Gc{i}' for i in range(24)]+['Gcphase']#['Gc16', 'Gzr']+['Gcphase']
big_pspec = pygsti.processors.QubitProcessorSpec(n, gate_names, availability=availability, qubit_labels=qubit_labels)

# %%
#let's hope pyGSTi knows how to do the qasm decompositions
exp = ibmq.IBMQExperiment(ced, big_pspec, circuits_per_batch = 100, num_shots = 5000)
# Out:
# Constructing job for circuit batch 1 of 96
# Constructing job for circuit batch 2 of 96
# Constructing job for circuit batch 3 of 96
# Constructing job for circuit batch 4 of 96
# Constructing job for circuit batch 5 of 96
# Constructing job for circuit batch 6 of 96
# Constructing job for circuit batch 7 of 96
# Constructing job for circuit batch 8 of 96
# Constructing job for circuit batch 9 of 96
# Constructing job for circuit batch 10 of 96
# Constructing job for circuit batch 11 of 96
# Constructing job for circuit batch 12 of 96
# Constructing job for circuit batch 13 of 96
# Constructing job for circuit batch 14 of 96
# Constructing job for circuit batch 15 of 96
# Constructing job for circuit batch 16 of 96
# Constructing job for circuit batch 17 of 96
# Constructing job for circuit batch 18 of 96
# Constructing job for circuit batch 19 of 96
# Constructing job for circuit batch 20 of 96
# Constructing job for circuit batch 21 of 96
# Constructing job for circuit batch 22 of 96
# Constructing job for circuit batch 23 of 96
# Constructing job for circuit batch 24 of 96
# Constructing job for circuit batch 25 of 96
# Constructing job for circuit batch 26 of 96
# Constructing job for circuit batch 27 of 96
# Constructing job for circuit batch 28 of 96
# Constructing job for circuit batch 29 of 96
# Constructing job for circuit batch 30 of 96
# Constructing job for circuit batch 31 of 96
# Constructing job for circuit batch 32 of 96
# Constructing job for circuit batch 33 of 96
# Constructing job for circuit batch 34 of 96
# Constructing job for circuit batch 35 of 96
# Constructing job for circuit batch 36 of 96
# Constructing job for circuit batch 37 of 96
# Constructing job for circuit batch 38 of 96
# Constructing job for circuit batch 39 of 96
# Constructing job for circuit batch 40 of 96
# Constructing job for circuit batch 41 of 96
# Constructing job for circuit batch 42 of 96
# Constructing job for circuit batch 43 of 96
# Constructing job for circuit batch 44 of 96
# Constructing job for circuit batch 45 of 96
# Constructing job for circuit batch 46 of 96
# Constructing job for circuit batch 47 of 96
# Constructing job for circuit batch 48 of 96
# Constructing job for circuit batch 49 of 96
# Constructing job for circuit batch 50 of 96
# Constructing job for circuit batch 51 of 96
# Constructing job for circuit batch 52 of 96
# Constructing job for circuit batch 53 of 96
# Constructing job for circuit batch 54 of 96
# Constructing job for circuit batch 55 of 96
# Constructing job for circuit batch 56 of 96
# Constructing job for circuit batch 57 of 96
# Constructing job for circuit batch 58 of 96
# Constructing job for circuit batch 59 of 96
# Constructing job for circuit batch 60 of 96
# Constructing job for circuit batch 61 of 96
# Constructing job for circuit batch 62 of 96
# Constructing job for circuit batch 63 of 96
# Constructing job for circuit batch 64 of 96
# Constructing job for circuit batch 65 of 96
# Constructing job for circuit batch 66 of 96
# Constructing job for circuit batch 67 of 96
# Constructing job for circuit batch 68 of 96
# Constructing job for circuit batch 69 of 96
# Constructing job for circuit batch 70 of 96
# Constructing job for circuit batch 71 of 96
# Constructing job for circuit batch 72 of 96
# Constructing job for circuit batch 73 of 96
# Constructing job for circuit batch 74 of 96
# Constructing job for circuit batch 75 of 96
# Constructing job for circuit batch 76 of 96
# Constructing job for circuit batch 77 of 96
# Constructing job for circuit batch 78 of 96
# Constructing job for circuit batch 79 of 96
# Constructing job for circuit batch 80 of 96
# Constructing job for circuit batch 81 of 96
# Constructing job for circuit batch 82 of 96
# Constructing job for circuit batch 83 of 96
# Constructing job for circuit batch 84 of 96
# Constructing job for circuit batch 85 of 96
# Constructing job for circuit batch 86 of 96
# Constructing job for circuit batch 87 of 96
# Constructing job for circuit batch 88 of 96
# Constructing job for circuit batch 89 of 96
# Constructing job for circuit batch 90 of 96
# Constructing job for circuit batch 91 of 96
# Constructing job for circuit batch 92 of 96
# Constructing job for circuit batch 93 of 96
# Constructing job for circuit batch 94 of 96
# Constructing job for circuit batch 95 of 96
# Constructing job for circuit batch 96 of 96

# %%
import qiskit
from qiskit.circuit.library import XGate
from qiskit.transpiler import PassManager, InstructionDurations
from qiskit.transpiler.passes import ALAPScheduleAnalysis, PadDynamicalDecoupling
from qiskit.visualization import timeline_drawer


def insert_dd(circ, backend):
    durations = qiskit.transpiler.InstructionDurations.from_backend(backend)
# balanced X-X sequence on all qubits
    dd_sequence = [XGate(), XGate()]
    pm = PassManager([ALAPScheduleAnalysis(durations),
                  PadDynamicalDecoupling(durations, dd_sequence)])
    circ_dd = pm.run(circ)
    return circ_dd

def add_dd_to_exp(exp, backend):
    for i, batch in enumerate(exp['qiskit_QuantumCircuits']):
        circuits = []
        for qiskit_circ in batch:
            circ_dd = insert_dd(qiskit_circ, backend)
            circuits.append(circ_dd)
        exp['qiskit_QuantumCircuits'][i] = circuits
    return exp

# %%
exp = add_dd_to_exp(exp,backend)

# %%
with backend.open_session() as session:
    exp.submit(backend)
# Out:
# /tmp/ipykernel_73903/4020636989.py:1: DeprecationWarning: backend.run() and related sessions methods are deprecated  as of qiskit-ibm-runtime 0.23 and will be removed no sooner than 6 months after the release date. More details can be found in the primitives migration guide https://docs.quantum.ibm.com/api/migration-guides/qiskit-runtime.
#   with backend.open_session() as session:
# Submitting batch 1
#   - Job ID is cs4m1sqkfpw00080m6tg
#   - Failed to get queue position for batch 1
# Submitting batch 2
#   - Job ID is cs4m1tf965y000857xc0
#   - Failed to get queue position for batch 2
# Submitting batch 3
#   - Job ID is cs4m1tzkfpw00080m6v0
#   - Failed to get queue position for batch 3
# Submitting batch 4
#   - Job ID is cs4m1vf75q40008tvtw0
#   - Failed to get queue position for batch 4
# Submitting batch 5
#   - Job ID is cs4m1w74amg00087p9ng
#   - Failed to get queue position for batch 5
# Submitting batch 6
#   - Job ID is cs4m1wq4amg00087p9p0
#   - Failed to get queue position for batch 6
# Submitting batch 7
#   - Job ID is cs4m1x7yhpyg008arbag
#   - Queue position is 1
# Submitting batch 8
#   - Job ID is cs4m1xqyhpyg008arbb0
#   - Queue position is 2
# Submitting batch 9
#   - Job ID is cs4m1y775q40008tvtwg
#   - Queue position is 3
# Submitting batch 10
#   - Job ID is cs4m1yqkfpw00080m6vg
#   - Queue position is 4
# Submitting batch 11
#   - Job ID is cs4m1z7kfpw00080m6w0
#   - Queue position is 5
# Submitting batch 12
#   - Job ID is cs4m1zqyhpyg008arbbg
#   - Queue position is 6
# Submitting batch 13
#   - Job ID is cs4m208bqt7g00823nt0
#   - Queue position is 7
# Submitting batch 14
#   - Job ID is cs4m20r965y000857xd0
#   - Queue position is 7
# Submitting batch 15
#   - Job ID is cs4m218kfpw00080m6wg
#   - Queue position is 8
# Submitting batch 16
#   - Job ID is cs4m220kfpw00080m6x0
#   - Queue position is 9
# Submitting batch 17
#   - Job ID is cs4m22g965y000857xdg
#   - Failed to get queue position for batch 17
# Submitting batch 18
#   - Job ID is cs4m2384amg00087p9pg
#   - Queue position is 11
# Submitting batch 19
#   - Job ID is cs4m23rbqt7g00823ntg
#   - Failed to get queue position for batch 19
# Submitting batch 20
#   - Job ID is cs4m24g75q40008tvtx0
#   - Queue position is 13
# Submitting batch 21
#   - Job ID is cs4m25g75q40008tvtxg
#   - Queue position is 14
# Submitting batch 22
#   - Job ID is cs4m26875q40008tvty0
#   - Queue position is 15
# Submitting batch 23
#   - Job ID is cs4m27075q40008tvtyg
#   - Queue position is 16
# Submitting batch 24
#   - Job ID is cs4m27g75q40008tvtz0
#   - Failed to get queue position for batch 24
# Submitting batch 25
#   - Job ID is cs4m289kfpw00080m6xg
#   - Queue position is 18
# Submitting batch 26
#   - Job ID is cs4m28s75q40008tvtzg
#   - Failed to get queue position for batch 26
# Submitting batch 27
#   - Job ID is cs4m2994amg00087p9q0
#   - Failed to get queue position for batch 27
# Submitting batch 28
#   - Job ID is cs4m29syhpyg008arbc0
#   - Failed to get queue position for batch 28
# Submitting batch 29
#   - Job ID is cs4m2ah965y000857xe0
#   - Failed to get queue position for batch 29
# Submitting batch 30
#   - Job ID is cs4m2b1kfpw00080m6y0
#   - Queue position is 23
# Submitting batch 31
#   - Job ID is cs4m2bh965y000857xeg
#   - Queue position is 24
# Submitting batch 32
#   - Job ID is cs4m2c9kfpw00080m6yg
#   - Queue position is 25
# Submitting batch 33
#   - Job ID is cs4m2csyhpyg008arbcg
#   - Queue position is 26
# Submitting batch 34
#   - Job ID is cs4m2d9965y000857xf0
#   - Queue position is 27
# Submitting batch 35
#   - Job ID is cs4m2dsyhpyg008arbd0
#   - Queue position is 28
# Submitting batch 36
#   - Job ID is cs4m2eskfpw00080m6z0
#   - Failed to get queue position for batch 36
# Submitting batch 37
#   - Job ID is cs4m2fhbqt7g00823nv0
#   - Failed to get queue position for batch 37
# Submitting batch 38
#   - Job ID is cs4m2g2965y000857xfg
#   - Queue position is 31
# Submitting batch 39
#   - Job ID is cs4m2gj4amg00087p9qg
#   - Failed to get queue position for batch 39
# Submitting batch 40
#   - Job ID is cs4m2hakfpw00080m6zg
#   - Failed to get queue position for batch 40
# Submitting batch 41
#   - Job ID is cs4m2jjkfpw00080m700
#   - Failed to get queue position for batch 41
# Submitting batch 42
#   - Job ID is cs4m2ka75q40008tvv0g
#   - Queue position is 35
# Submitting batch 43
#   - Job ID is cs4m2ktbqt7g00823nvg
#   - Failed to get queue position for batch 43
# Submitting batch 44
#   - Job ID is cs4m2ma75q40008tvv10
#   - Failed to get queue position for batch 44
# Submitting batch 45
#   - Job ID is cs4m2mtkfpw00080m70g
#   - Queue position is 38
# Submitting batch 46
#   - Job ID is cs4m2p2965y000857xg0
#   - Failed to get queue position for batch 46
# Submitting batch 47
#   - Job ID is cs4m2pjkfpw00080m710
#   - Failed to get queue position for batch 47
# Submitting batch 48
#   - Job ID is cs4m2qa75q40008tvv1g
#   - Failed to get queue position for batch 48
# Submitting batch 49
#   - Job ID is cs4m2qtkfpw00080m71g
#   - Failed to get queue position for batch 49
# Submitting batch 50
#   - Job ID is cs4m2rb965y000857xgg
#   - Failed to get queue position for batch 50
# Submitting batch 51
#   - Job ID is cs4m2rv75q40008tvv20
#   - Failed to get queue position for batch 51
# Submitting batch 52
#   - Job ID is cs4m2skyhpyg008arbdg
#   - Failed to get queue position for batch 52
# Submitting batch 53
#   - Job ID is cs4m2tb75q40008tvv2g
#   - Failed to get queue position for batch 53
# Submitting batch 54
#   - Job ID is cs4m2tvyhpyg008arbe0
#   - Failed to get queue position for batch 54
# Submitting batch 55
#   - Job ID is cs4m2vkkfpw00080m72g
#   - Failed to get queue position for batch 55
# Submitting batch 56
#   - Job ID is cs4m2w375q40008tvv30
#   - Failed to get queue position for batch 56
# Submitting batch 57
#   - Job ID is cs4m2wv75q40008tvv3g
#   - Failed to get queue position for batch 57
# Submitting batch 58
#   - Job ID is cs4m2xbyhpyg008arbeg
#   - Failed to get queue position for batch 58
# Submitting batch 59
#   - Job ID is cs4m2y3kfpw00080m730
#   - Failed to get queue position for batch 59
# Submitting batch 60
#   - Job ID is cs4m2ykyhpyg008arbf0
#   - Failed to get queue position for batch 60
# Submitting batch 61
#   - Job ID is cs4m2z3yhpyg008arbfg
#   - Failed to get queue position for batch 61
# Submitting batch 62
#   - Job ID is cs4m2zk965y000857xh0
#   - Failed to get queue position for batch 62
# Submitting batch 63
#   - Job ID is cs4m304965y000857xhg
#   - Failed to get queue position for batch 63
# Submitting batch 64
#   - Job ID is cs4m30wkfpw00080m73g
#   - Failed to get queue position for batch 64
# Submitting batch 65
#   - Job ID is cs4m31cyhpyg008arbg0
#   - Failed to get queue position for batch 65
# Submitting batch 66
#   - Job ID is cs4m3244amg00087p9r0
#   - Failed to get queue position for batch 66
# Submitting batch 67
#   - Job ID is cs4m32mbqt7g00823nw0
#   - Failed to get queue position for batch 67
# Submitting batch 68
#   - Job ID is cs4m334kfpw00080m740
#   - Failed to get queue position for batch 68
# Submitting batch 69
#   - Job ID is cs4m33w75q40008tvv40
#   - Failed to get queue position for batch 69
# Submitting batch 70
#   - Job ID is cs4m34cyhpyg008arbgg
#   - Failed to get queue position for batch 70
# Submitting batch 71
#   - Job ID is cs4m34w965y000857xj0
#   - Failed to get queue position for batch 71
# Submitting batch 72
#   - Job ID is cs4m35c75q40008tvv4g
#   - Failed to get queue position for batch 72
# Submitting batch 73
#   - Job ID is cs4m364kfpw00080m74g
#   - Failed to get queue position for batch 73
# Submitting batch 74
#   - Job ID is cs4m36m965y000857xjg
#   - Failed to get queue position for batch 74
# Submitting batch 75
#   - Job ID is cs4m374965y000857xk0
#   - Failed to get queue position for batch 75
# Submitting batch 76
#   - Job ID is cs4m37m75q40008tvv50
#   - Failed to get queue position for batch 76
# Submitting batch 77
#   - Job ID is cs4m38575q40008tvv5g
#   - Failed to get queue position for batch 77
# Submitting batch 78
#   - Job ID is cs4m38x965y000857xkg
#   - Failed to get queue position for batch 78
# Submitting batch 79
#   - Job ID is cs4m39dkfpw00080m750
#   - Failed to get queue position for batch 79
# Submitting batch 80
#   - Job ID is cs4m39x75q40008tvv60
#   - Failed to get queue position for batch 80
# Submitting batch 81
#   - Job ID is cs4m3anbqt7g00823nwg
#   - Failed to get queue position for batch 81
# Submitting batch 82
#   - Job ID is cs4m3b575q40008tvv6g
#   - Failed to get queue position for batch 82
# Submitting batch 83
#   - Job ID is cs4m3bnbqt7g00823nx0
#   - Failed to get queue position for batch 83
# Submitting batch 84
#   - Job ID is cs4m3c54amg00087p9rg
#   - Failed to get queue position for batch 84
# Submitting batch 85
#   - Job ID is cs4m3cxyhpyg008arbhg
#   - Failed to get queue position for batch 85
# Submitting batch 86
#   - Job ID is cs4m3dd4amg00087p9s0
#   - Failed to get queue position for batch 86
# Submitting batch 87
#   - Job ID is cs4m3e575q40008tvv70
#   - Failed to get queue position for batch 87
# Submitting batch 88
#   - Job ID is cs4m3en965y000857xm0
#   - Failed to get queue position for batch 88
# Submitting batch 89
#   - Job ID is cs4m3f5kfpw00080m75g
#   - Failed to get queue position for batch 89
# Submitting batch 90
#   - Job ID is cs4m3fn965y000857xmg
#   - Failed to get queue position for batch 90
# Submitting batch 91
#   - Job ID is cs4m3geyhpyg008arbj0
#   - Failed to get queue position for batch 91
# Submitting batch 92
#   - Job ID is cs4m3gy75q40008tvv7g
#   - Failed to get queue position for batch 92
# Submitting batch 93
#   - Job ID is cs4m3heyhpyg008arbjg
#   - Failed to get queue position for batch 93
# Submitting batch 94
#   - Job ID is cs4m3hykfpw00080m760
#   - Failed to get queue position for batch 94
# Submitting batch 95
#   - Job ID is cs4m3jpyhpyg008arbk0
#   - Failed to get queue position for batch 95
# Submitting batch 96
#   - Job ID is cs4m3k6yhpyg008arbkg
#   - Failed to get queue position for batch 96

# %%
exp.monitor()
# Out:
# Batch 1: JobStatus.DONE
# Batch 2: JobStatus.DONE
# Batch 3: JobStatus.DONE
# Batch 4: JobStatus.DONE
# Batch 5: JobStatus.DONE
# Batch 6: JobStatus.DONE
# Batch 7: JobStatus.DONE
# Batch 8: JobStatus.DONE
# Batch 9: JobStatus.DONE
# Batch 10: JobStatus.DONE
# Batch 11: JobStatus.DONE
# Batch 12: JobStatus.DONE
# Batch 13: JobStatus.DONE
# Batch 14: JobStatus.DONE
# Batch 15: JobStatus.DONE
# Batch 16: JobStatus.DONE
# Batch 17: JobStatus.DONE
# Batch 18: JobStatus.DONE
# Batch 19: JobStatus.DONE
# Batch 20: JobStatus.DONE
# Batch 21: JobStatus.DONE
# Batch 22: JobStatus.DONE
# Batch 23: JobStatus.DONE
# Batch 24: JobStatus.DONE
# Batch 25: JobStatus.DONE
# Batch 26: JobStatus.DONE
# Batch 27: JobStatus.DONE
# Batch 28: JobStatus.DONE
# Batch 29: JobStatus.DONE
# Batch 30: JobStatus.DONE
# Batch 31: JobStatus.DONE
# Batch 32: JobStatus.DONE
# Batch 33: JobStatus.DONE
# Batch 34: JobStatus.DONE
# Batch 35: JobStatus.DONE
# Batch 36: JobStatus.DONE
# Batch 37: JobStatus.DONE
# Batch 38: JobStatus.DONE
# Batch 39: JobStatus.DONE
# Batch 40: JobStatus.DONE
# Batch 41: JobStatus.DONE
# Batch 42: JobStatus.DONE
# Batch 43: JobStatus.DONE
# Batch 44: JobStatus.DONE
# Batch 45: JobStatus.DONE
# Batch 46: JobStatus.DONE
# Batch 47: JobStatus.DONE
# Batch 48: JobStatus.DONE
# Batch 49: JobStatus.DONE
# Batch 50: JobStatus.DONE
# Batch 51: JobStatus.DONE
# Batch 52: JobStatus.DONE
# Batch 53: JobStatus.DONE
# Batch 54: JobStatus.DONE
# Batch 55: JobStatus.DONE
# Batch 56: JobStatus.DONE
# Batch 57: JobStatus.DONE
# Batch 58: JobStatus.DONE
# Batch 59: JobStatus.DONE
# Batch 60: JobStatus.DONE
# Batch 61: JobStatus.DONE
# Batch 62: JobStatus.DONE
# Batch 63: JobStatus.DONE
# Batch 64: JobStatus.DONE
# Batch 65: JobStatus.DONE
# Batch 66: JobStatus.DONE
# Batch 67: JobStatus.DONE
# Batch 68: JobStatus.DONE
# Batch 69: JobStatus.DONE
# Batch 70: JobStatus.DONE
# Batch 71: JobStatus.DONE
# Batch 72: JobStatus.DONE
# Batch 73: JobStatus.DONE
# Batch 74: JobStatus.DONE
# Batch 75: JobStatus.DONE
# Batch 76: JobStatus.DONE
# Batch 77: JobStatus.DONE
# Batch 78: JobStatus.DONE
# Batch 79: JobStatus.DONE
# Batch 80: JobStatus.DONE
# Batch 81: JobStatus.DONE
# Batch 82: JobStatus.DONE
# Batch 83: JobStatus.DONE
# Batch 84: JobStatus.DONE
# Batch 85: JobStatus.DONE
# Batch 86: JobStatus.DONE
# Batch 87: JobStatus.DONE
# Batch 88: JobStatus.ERROR
# Batch 89: JobStatus.ERROR
# Batch 90: JobStatus.ERROR
# Batch 91: JobStatus.ERROR
# Batch 92: JobStatus.ERROR
# Batch 93: JobStatus.ERROR
# Batch 94: JobStatus.ERROR
# Batch 95: JobStatus.ERROR
# Batch 96: JobStatus.ERROR

# %%
def to_labeled_counts(input_dict, ordered_target_indices, num_qubits_in_pspec): 
    outcome_labels = []
    counts_data = []
    for bitstring, count in input_dict.items():
        new_label = []
        term_string = ''
        term_bits = bitstring[:num_qubits_in_pspec][::-1]
        mid_bits = bitstring[num_qubits_in_pspec:][::-1]
        for index in ordered_target_indices:
            term_string += term_bits[index]
        for bit in mid_bits:
            new_label.append('p'+bit)
        new_label.append(term_string)
        outcome_labels.append(tuple(new_label))
        counts_data.append(count)
    return outcome_labels, counts_data

# %%
#exp.retrieve_results()
exp['batch_result_object'] = []
#get results from backend jobs and add to dict
ds = pygsti.data.DataSet()
for exp_idx, qjob in enumerate(exp['qjob']):
    print("Querying IBMQ for results objects for batch {}...".format(exp_idx + 1))
    try:
        batch_result = qjob.result()
        exp['batch_result_object'].append(batch_result)
        #exp_dict['batch_data'] = []
        num_qubits_in_pspec = exp['pspec'].num_qubits
        for i, circ in enumerate(exp['pygsti_circuits'][exp_idx]): 
            ordered_target_indices = [exp['pspec'].qubit_labels.index(q) for q in circ.line_labels]
            #assumes qubit labeling of the form 'Q0' not '0' 
            labeled_counts = to_labeled_counts(batch_result.get_counts(i), ordered_target_indices, num_qubits_in_pspec)
            outcome_labels = labeled_counts[0]
            counts_data = labeled_counts[1]
            ds.add_count_list(circ, outcome_labels, counts_data)
    except:
        print('failed to retrieve batch')
exp['data'] = pygsti.protocols.ProtocolData(exp['edesign'], ds)
print('Finished retrieving results!') #Changed this
# Out:
# Querying IBMQ for results objects for batch 1...
# Querying IBMQ for results objects for batch 2...
# Querying IBMQ for results objects for batch 3...
# Querying IBMQ for results objects for batch 4...
# Querying IBMQ for results objects for batch 5...
# Querying IBMQ for results objects for batch 6...
# Querying IBMQ for results objects for batch 7...
# Querying IBMQ for results objects for batch 8...
# Querying IBMQ for results objects for batch 9...
# Querying IBMQ for results objects for batch 10...
# Querying IBMQ for results objects for batch 11...
# Querying IBMQ for results objects for batch 12...
# Querying IBMQ for results objects for batch 13...
# Querying IBMQ for results objects for batch 14...
# Querying IBMQ for results objects for batch 15...
# Querying IBMQ for results objects for batch 16...
# Querying IBMQ for results objects for batch 17...
# Querying IBMQ for results objects for batch 18...
# Querying IBMQ for results objects for batch 19...
# Querying IBMQ for results objects for batch 20...
# Querying IBMQ for results objects for batch 21...
# Querying IBMQ for results objects for batch 22...
# Querying IBMQ for results objects for batch 23...
# Querying IBMQ for results objects for batch 24...
# Querying IBMQ for results objects for batch 25...
# Querying IBMQ for results objects for batch 26...
# Querying IBMQ for results objects for batch 27...
# Querying IBMQ for results objects for batch 28...
# Querying IBMQ for results objects for batch 29...
# Querying IBMQ for results objects for batch 30...
# Querying IBMQ for results objects for batch 31...
# Querying IBMQ for results objects for batch 32...
# Querying IBMQ for results objects for batch 33...
# Querying IBMQ for results objects for batch 34...
# Querying IBMQ for results objects for batch 35...
# Querying IBMQ for results objects for batch 36...
# Querying IBMQ for results objects for batch 37...
# Querying IBMQ for results objects for batch 38...
# Querying IBMQ for results objects for batch 39...
# Querying IBMQ for results objects for batch 40...
# Querying IBMQ for results objects for batch 41...
# Querying IBMQ for results objects for batch 42...
# Querying IBMQ for results objects for batch 43...
# Querying IBMQ for results objects for batch 44...
# Querying IBMQ for results objects for batch 45...
# Querying IBMQ for results objects for batch 46...
# Querying IBMQ for results objects for batch 47...
# Querying IBMQ for results objects for batch 48...
# Querying IBMQ for results objects for batch 49...
# Querying IBMQ for results objects for batch 50...
# Querying IBMQ for results objects for batch 51...
# Querying IBMQ for results objects for batch 52...
# Querying IBMQ for results objects for batch 53...
# Querying IBMQ for results objects for batch 54...
# Querying IBMQ for results objects for batch 55...
# Querying IBMQ for results objects for batch 56...
# Querying IBMQ for results objects for batch 57...
# Querying IBMQ for results objects for batch 58...
# Querying IBMQ for results objects for batch 59...
# Querying IBMQ for results objects for batch 60...
# Querying IBMQ for results objects for batch 61...
# Querying IBMQ for results objects for batch 62...
# Querying IBMQ for results objects for batch 63...
# Querying IBMQ for results objects for batch 64...
# Querying IBMQ for results objects for batch 65...
# Querying IBMQ for results objects for batch 66...
# Querying IBMQ for results objects for batch 67...
# Querying IBMQ for results objects for batch 68...
# Querying IBMQ for results objects for batch 69...
# Querying IBMQ for results objects for batch 70...
# Querying IBMQ for results objects for batch 71...
# Querying IBMQ for results objects for batch 72...
# Querying IBMQ for results objects for batch 73...
# Querying IBMQ for results objects for batch 74...
# Querying IBMQ for results objects for batch 75...
# Querying IBMQ for results objects for batch 76...
# Querying IBMQ for results objects for batch 77...
# Querying IBMQ for results objects for batch 78...
# Querying IBMQ for results objects for batch 79...
# Querying IBMQ for results objects for batch 80...
# Querying IBMQ for results objects for batch 81...
# Querying IBMQ for results objects for batch 82...
# Querying IBMQ for results objects for batch 83...
# Querying IBMQ for results objects for batch 84...
# Querying IBMQ for results objects for batch 85...
# Querying IBMQ for results objects for batch 86...
# Querying IBMQ for results objects for batch 87...
# Querying IBMQ for results objects for batch 88...
# Querying IBMQ for results objects for batch 89...
# Querying IBMQ for results objects for batch 90...
# Querying IBMQ for results objects for batch 91...
# Querying IBMQ for results objects for batch 92...
# Querying IBMQ for results objects for batch 93...
# Querying IBMQ for results objects for batch 94...
# Querying IBMQ for results objects for batch 95...
# Querying IBMQ for results objects for batch 96...
# Finished retrieving results!

# %%
pd = exp['data']
pd.write('05_18_test_mcmcb_ibm_osaka')
